# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### LOADING DATASET

# %%
malaria_df = pd.read_csv('DatasetAfricaMalaria.csv')

# %%
malaria_df.head()
# Out:
#    Country Name  Year Country Code  \
# 0       Algeria  2007          DZA
# 1        Angola  2007          AGO
# 2         Benin  2007          BEN
# 3      Botswana  2007          BWA
# 4  Burkina Faso  2007          BFA
#
#    Incidence of malaria (per 1,000 population at risk)  \
# 0                                               0.01
# 1                                             286.72
# 2                                             480.24
# 3                                               1.03
# 4                                             503.80
#
#    Malaria cases reported  \
# 0                    26.0
# 1               1533485.0
# 2                     0.0
# 3                   390.0
# 4                 44246.0
#
#    Use of insecticide-treated bed nets (% of under-5 population)  \
# 0                                                NaN
# 1                                               18.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Children with fever receiving antimalarial drugs (% of children under age 5 with fever)  \
# 0                                                NaN
# 1                                               29.8
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)  \
# 0                                                NaN
# 1                                                1.5
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    People using safely managed drinking water services (% of population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    People using safely managed drinking water services, rural (% of rural population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  Urban population growth (annual %)  \
# 0  ...                                2.71
# 1  ...                                5.01
# 2  ...                                4.09
# 3  ...                                4.80
# 4  ...                                5.91
#
#    People using at least basic drinking water services (% of population)  \
# 0                                              91.68
# 1                                              47.96
# 2                                              63.78
# 3                                              78.89
# 4                                              52.27
#
#    People using at least basic drinking water services, rural (% of rural population)  \
# 0                                              85.83
# 1                                              23.77
# 2                                              54.92
# 3                                              57.60
# 4                                              45.13
#
#    People using at least basic drinking water services, urban (% of urban population)  \
# 0                                              94.78
# 1                                              65.83
# 2                                              76.24
# 3                                              94.35
# 4                                              76.15
#
#    People using at least basic sanitation services (% of population)  \
# 0                                              85.85
# 1                                              37.26
# 2                                              11.80
# 3                                              61.60
# 4                                              15.60
#
#    People using at least basic sanitation services, rural (% of rural population)  \
# 0                                              76.94
# 1                                              14.00
# 2                                               4.29
# 3                                              39.99
# 4                                               6.38
#
#    People using at least basic sanitation services, urban  (% of urban population)  \
# 0                                              90.57
# 1                                              54.44
# 2                                              22.36
# 3                                              77.30
# 4                                              46.49
#
#     latitude  longitude                            geometry
# 0  28.033886   1.659626          POINT (28.033886 1.659626)
# 1 -11.202692  17.873887        POINT (-11.202692 17.873887)
# 2   9.307690   2.315834  POINT (9.307689999999999 2.315834)
# 3 -22.328474  24.684866        POINT (-22.328474 24.684866)
# 4  12.238333  -1.561593         POINT (12.238333 -1.561593)
#
# [5 rows x 27 columns]

# %% [markdown]
# ## DATA ASSESSMENT AND INVESTIGATION

# %% [markdown]
# #### Checking the data types and non-null counts

# %%
malaria_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 27 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   Country Name                                                                             594 non-null    object
#  1   Year                                                                                     594 non-null    int64
#  2   Country Code                                                                             594 non-null    object
#  3   Incidence of malaria (per 1,000 population at risk)                                      550 non-null    float64
#  4   Malaria cases reported                                                                   550 non-null    float64
#  5   Use of insecticide-treated bed nets (% of under-5 population)                            132 non-null    float64
#  6   Children with fever receiving antimalarial drugs (% of children under age 5 with fever)  122 non-null    float64
#  7   Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)    106 non-null    float64
#  8   People using safely managed drinking water services (% of population)                    99 non-null     float64
#  9   People using safely managed drinking water services, rural (% of rural population)       88 non-null     float64
#  10  People using safely managed drinking water services, urban (% of urban population)       176 non-null    float64
#  11  People using safely managed sanitation services (% of population)                        132 non-null    float64
#  12  People using safely managed sanitation services, rural (% of rural population)           110 non-null    float64
#  13  People using safely managed sanitation services, urban  (% of urban population)          132 non-null    float64
#  14  Rural population (% of total population)                                                 588 non-null    float64
#  15  Rural population growth (annual %)                                                       588 non-null    float64
#  16  Urban population (% of total population)                                                 588 non-null    float64
#  17  Urban population growth (annual %)                                                       588 non-null    float64
#  18  People using at least basic drinking water services (% of population)                    588 non-null    float64
#  19  People using at least basic drinking water services, rural (% of rural population)       566 non-null    float64
#  20  People using at least basic drinking water services, urban (% of urban population)       566 non-null    float64
#  21  People using at least basic sanitation services (% of population)                        588 non-null    float64
#  22  People using at least basic sanitation services, rural (% of rural population)           566 non-null    float64
#  23  People using at least basic sanitation services, urban  (% of urban population)          566 non-null    float64
#  24  latitude                                                                                 594 non-null    float64
#  25  longitude                                                                                594 non-null    float64
#  26  geometry                                                                                 594 non-null    object
# dtypes: float64(23), int64(1), object(3)
# memory usage: 125.4+ KB

# %% [markdown]
# #### Statistical Summary of numeric columns

# %%
malaria_df.describe()
# Out:
#               Year  Incidence of malaria (per 1,000 population at risk)  \
# count   594.000000                                         550.000000
# mean   2012.000000                                         190.087491
# std       3.164943                                         163.054527
# min    2007.000000                                           0.000000
# 25%    2009.000000                                          30.857500
# 50%    2012.000000                                         174.775000
# 75%    2015.000000                                         347.637500
# max    2017.000000                                         585.540000
#
#        Malaria cases reported  \
# count            5.500000e+02
# mean             1.068330e+06
# std              2.192802e+06
# min              0.000000e+00
# 25%              2.211750e+03
# 50%              1.130260e+05
# 75%              1.154808e+06
# max              1.682113e+07
#
#        Use of insecticide-treated bed nets (% of under-5 population)  \
# count                                         132.000000
# mean                                           42.530303
# std                                            20.157059
# min                                             1.000000
# 25%                                            26.675000
# 50%                                            42.900000
# 75%                                            56.325000
# max                                            95.500000
#
#        Children with fever receiving antimalarial drugs (% of children under age 5 with fever)  \
# count                                         122.000000
# mean                                           30.201639
# std                                            18.903198
# min                                             0.500000
# 25%                                            17.275000
# 50%                                            29.300000
# 75%                                            42.625000
# max                                            76.900000
#
#        Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)  \
# count                                         106.000000
# mean                                           15.013958
# std                                            12.389166
# min                                             0.000000
# 25%                                             5.763285
# 50%                                            11.500000
# 75%                                            21.850000
# max                                            59.600000
#
#        People using safely managed drinking water services (% of population)  \
# count                                          99.000000
# mean                                           33.478990
# std                                            26.678321
# min                                             5.770000
# 25%                                             8.975000
# 50%                                            28.390000
# 75%                                            43.890000
# max                                            92.660000
#
#        People using safely managed drinking water services, rural (% of rural population)  \
# count                                          88.000000
# mean                                           12.470568
# std                                            10.078371
# min                                             0.930000
# 25%                                             4.185000
# 50%                                            10.675000
# 75%                                            16.887500
# max                                            39.930000
#
#        People using safely managed drinking water services, urban (% of urban population)  \
# count                                         176.000000
# mean                                           51.549545
# std                                            24.157416
# min                                            11.200000
# 25%                                            34.125000
# 50%                                            51.365000
# 75%                                            70.747500
# max                                            89.540000
#
#        People using safely managed sanitation services (% of population)  ...  \
# count                                         132.000000                  ...
# mean                                           28.768939                  ...
# std                                            18.631510                  ...
# min                                             6.370000                  ...
# 25%                                            16.532500                  ...
# 50%                                            25.410000                  ...
# 75%                                            35.725000                  ...
# max                                            78.120000                  ...
#
#        Urban population (% of total population)  \
# count                                588.000000
# mean                                  43.164116
# std                                   18.086118
# min                                    9.860000
# 25%                                   28.795000
# 50%                                   41.560000
# 75%                                   56.945000
# max                                   88.980000
#
#        Urban population growth (annual %)  \
# count                          588.000000
# mean                             3.523061
# std                              1.456244
# min                             -4.650000
# 25%                              2.512500
# 50%                              3.730000
# 75%                              4.450000
# max                              7.400000
#
#        People using at least basic drinking water services (% of population)  \
# count                                         588.000000
# mean                                           65.994915
# std                                            17.283361
# min                                            28.960000
# 25%                                            52.375000
# 50%                                            64.470000
# 75%                                            79.165000
# max                                            99.870000
#
#        People using at least basic drinking water services, rural (% of rural population)  \
# count                                         566.000000
# mean                                           51.449576
# std                                            18.927868
# min                                            17.050000
# 25%                                            37.075000
# 50%                                            50.435000
# 75%                                            62.245000
# max                                            99.830000
#
#        People using at least basic drinking water services, urban (% of urban population)  \
# count                                         566.000000
# mean                                           84.268498
# std                                             9.307285
# min                                            52.010000
# 25%                                            78.080000
# 50%                                            85.420000
# 75%                                            90.082500
# max                                            99.920000
#
#        People using at least basic sanitation services (% of population)  \
# count                                         588.000000
# mean                                           39.469796
# std                                            26.304934
# min                                             4.990000
# 25%                                            18.197500
# 50%                                            32.555000
# 75%                                            54.810000
# max                                           100.000000
#
#        People using at least basic sanitation services, rural (% of rural population)  \
# count                                         566.000000
# mean                                           28.077208
# std                                            24.046725
# min                                             1.890000
# 25%                                             8.842500
# 50%                                            18.815000
# 75%                                            38.082500
# max                                            95.180000
#
#        People using at least basic sanitation services, urban  (% of urban population)  \
# count                                         566.000000
# mean                                           48.088375
# std                                            21.802128
# min                                            12.580000
# 25%                                            30.775000
# 50%                                            44.695000
# 75%                                            58.845000
# max                                            98.300000
#
#          latitude   longitude
# count  594.000000  594.000000
# mean     2.828796   17.342546
# std     15.678226   20.041257
# min    -30.559482  -24.013197
# 25%     -6.369028    0.824782
# 50%      6.744051   18.611308
# 75%     12.862807   31.465866
# max     33.886917   57.552152
#
# [8 rows x 24 columns]

# %% [markdown]
# #### Confirming Column Names

# %%
list(malaria_df)
# Out:
# ['Country Name',
#  'Year',
#  'Country Code',
#  'Incidence of malaria (per 1,000 population at risk)',
#  'Malaria cases reported',
#  'Use of insecticide-treated bed nets (% of under-5 population)',
#  'Children with fever receiving antimalarial drugs (% of children under age 5 with fever)',
#  'Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)',
#  'People using safely managed drinking water services (% of population)',
#  'People using safely managed drinking water services, rural (% of rural population)',
#  'People using safely managed drinking water services, urban (% of urban population)',
#  'People using safely managed sanitation services (% of population)',
#  'People using safely managed sanitation services, rural (% of rural population)',
#  'People using safely managed sanitation services, urban  (% of urban population)',
#  'Rural population (% of total population)',
#  'Rural population growth (annual %)',
#  'Urban population (% of total population)',
#  'Urban population growth (annual %)',
#  'People using at least basic drinking water services (% of population)',
#  'People using at least basic drinking water services, rural (% of rural population)',
#  'People using at least basic drinking water services, urban (% of urban population)',
#  'People using at least basic sanitation services (% of population)',
#  'People using at least basic sanitation services, rural (% of rural population)',
#  'People using at least basic sanitation services, urban  (% of urban population)',
#  'latitude',
#  'longitude',
#  'geometry']

# %% [markdown]
# #### Checking for total number of rows

# %%
len(malaria_df)
# Out:
# 594

# %% [markdown]
# #### Checking for missing Values (NULL only)

# %%
malaria_df.isnull()
# Out:
#      Country Name   Year  Country Code  \
# 0           False  False         False
# 1           False  False         False
# 2           False  False         False
# 3           False  False         False
# 4           False  False         False
# ..            ...    ...           ...
# 589         False  False         False
# 590         False  False         False
# 591         False  False         False
# 592         False  False         False
# 593         False  False         False
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 589                                              False
# 590                                               True
# 591                                              False
# 592                                              False
# 593                                              False
#
#      Malaria cases reported  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ..                      ...
# 589                   False
# 590                    True
# 591                   False
# 592                   False
# 593                   False
#
#      Use of insecticide-treated bed nets (% of under-5 population)  \
# 0                                                 True
# 1                                                False
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 589                                              False
# 590                                               True
# 591                                               True
# 592                                               True
# 593                                               True
#
#      Children with fever receiving antimalarial drugs (% of children under age 5 with fever)  \
# 0                                                 True
# 1                                                False
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 589                                              False
# 590                                               True
# 591                                               True
# 592                                               True
# 593                                               True
#
#      Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)  \
# 0                                                 True
# 1                                                False
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 589                                              False
# 590                                               True
# 591                                               True
# 592                                               True
# 593                                               True
#
#      People using safely managed drinking water services (% of population)  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 589                                               True
# 590                                              False
# 591                                              False
# 592                                               True
# 593                                               True
#
#      People using safely managed drinking water services, rural (% of rural population)  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 589                                               True
# 590                                               True
# 591                                              False
# 592                                               True
# 593                                               True
#
#      ...  Urban population growth (annual %)  \
# 0    ...                               False
# 1    ...                               False
# 2    ...                               False
# 3    ...                               False
# 4    ...                               False
# ..   ...                                 ...
# 589  ...                               False
# 590  ...                               False
# 591  ...                               False
# 592  ...                               False
# 593  ...                               False
#
#      People using at least basic drinking water services (% of population)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 589                                              False
# 590                                              False
# 591                                              False
# 592                                              False
# 593                                              False
#
#      People using at least basic drinking water services, rural (% of rural population)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 589                                              False
# 590                                              False
# 591                                              False
# 592                                              False
# 593                                              False
#
#      People using at least basic drinking water services, urban (% of urban population)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 589                                              False
# 590                                              False
# 591                                              False
# 592                                              False
# 593                                              False
#
#      People using at least basic sanitation services (% of population)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 589                                              False
# 590                                              False
# 591                                              False
# 592                                              False
# 593                                              False
#
#      People using at least basic sanitation services, rural (% of rural population)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 589                                              False
# 590                                              False
# 591                                              False
# 592                                              False
# 593                                              False
#
#      People using at least basic sanitation services, urban  (% of urban population)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 589                                              False
# 590                                              False
# 591                                              False
# 592                                              False
# 593                                              False
#
#      latitude  longitude  geometry
# 0       False      False     False
# 1       False      False     False
# 2       False      False     False
# 3       False      False     False
# 4       False      False     False
# ..        ...        ...       ...
# 589     False      False     False
# 590     False      False     False
# 591     False      False     False
# 592     False      False     False
# 593     False      False     False
#
# [594 rows x 27 columns]

# %% [markdown]
# #### Column Names with total number of missing values

# %%
malaria_df.isnull().sum()
# Out:
# Country Name                                                                                 0
# Year                                                                                         0
# Country Code                                                                                 0
# Incidence of malaria (per 1,000 population at risk)                                         44
# Malaria cases reported                                                                      44
# Use of insecticide-treated bed nets (% of under-5 population)                              462
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever)    472
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)      488
# People using safely managed drinking water services (% of population)                      495
# People using safely managed drinking water services, rural (% of rural population)         506
# People using safely managed drinking water services, urban (% of urban population)         418
# People using safely managed sanitation services (% of population)                          462
# People using safely managed sanitation services, rural (% of rural population)             484
# People using safely managed sanitation services, urban  (% of urban population)            462
# Rural population (% of total population)                                                     6
# Rural population growth (annual %)                                                           6
# Urban population (% of total population)                                                     6
# Urban population growth (annual %)                                                           6
# People using at least basic drinking water services (% of population)                        6
# People using at least basic drinking water services, rural (% of rural population)          28
# People using at least basic drinking water services, urban (% of urban population)          28
# People using at least basic sanitation services (% of population)                            6
# People using at least basic sanitation services, rural (% of rural population)              28
# People using at least basic sanitation services, urban  (% of urban population)             28
# latitude                                                                                     0
# longitude                                                                                    0
# geometry                                                                                     0
# dtype: int64

# %% [markdown]
# #### Checking for specific rows with missing values (NaN)

# %%
malaria_df[malaria_df.isnull().any(axis=1)]
# Out:
#      Country Name  Year Country Code  \
# 0         Algeria  2007          DZA
# 1          Angola  2007          AGO
# 2           Benin  2007          BEN
# 3        Botswana  2007          BWA
# 4    Burkina Faso  2007          BFA
# ..            ...   ...          ...
# 589          Togo  2017          TGO
# 590       Tunisia  2017          TUN
# 591        Uganda  2017          UGA
# 592        Zambia  2017          ZMB
# 593      Zimbabwe  2017          ZWE
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 0                                                 0.01
# 1                                               286.72
# 2                                               480.24
# 3                                                 1.03
# 4                                               503.80
# ..                                                 ...
# 589                                             278.20
# 590                                                NaN
# 591                                             336.76
# 592                                             160.05
# 593                                             108.55
#
#      Malaria cases reported  \
# 0                      26.0
# 1                 1533485.0
# 2                       0.0
# 3                     390.0
# 4                   44246.0
# ..                      ...
# 589               1755577.0
# 590                     NaN
# 591              11667831.0
# 592               5505639.0
# 593                467508.0
#
#      Use of insecticide-treated bed nets (% of under-5 population)  \
# 0                                                  NaN
# 1                                                 18.0
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 589                                               69.7
# 590                                                NaN
# 591                                                NaN
# 592                                                NaN
# 593                                                NaN
#
#      Children with fever receiving antimalarial drugs (% of children under age 5 with fever)  \
# 0                                                  NaN
# 1                                                 29.8
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 589                                               31.1
# 590                                                NaN
# 591                                                NaN
# 592                                                NaN
# 593                                                NaN
#
#      Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)  \
# 0                                                  NaN
# 1                                                  1.5
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 589                                               41.7
# 590                                                NaN
# 591                                                NaN
# 592                                                NaN
# 593                                                NaN
#
#      People using safely managed drinking water services (% of population)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 589                                                NaN
# 590                                              92.66
# 591                                               7.07
# 592                                                NaN
# 593                                                NaN
#
#      People using safely managed drinking water services, rural (% of rural population)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 589                                                NaN
# 590                                                NaN
# 591                                               4.46
# 592                                                NaN
# 593                                                NaN
#
#      ...  Urban population growth (annual %)  \
# 0    ...                                2.71
# 1    ...                                5.01
# 2    ...                                4.09
# 3    ...                                4.80
# 4    ...                                5.91
# ..   ...                                 ...
# 589  ...                                3.79
# 590  ...                                1.57
# 591  ...                                6.25
# 592  ...                                4.21
# 593  ...                                1.28
#
#      People using at least basic drinking water services (% of population)  \
# 0                                                91.68
# 1                                                47.96
# 2                                                63.78
# 3                                                78.89
# 4                                                52.27
# ..                                                 ...
# 589                                              65.13
# 590                                              96.25
# 591                                              49.10
# 592                                              59.96
# 593                                              64.05
#
#      People using at least basic drinking water services, rural (% of rural population)  \
# 0                                                85.83
# 1                                                23.77
# 2                                                54.92
# 3                                                57.60
# 4                                                45.13
# ..                                                 ...
# 589                                              48.39
# 590                                              88.71
# 591                                              41.25
# 592                                              41.95
# 593                                              49.80
#
#      People using at least basic drinking water services, urban (% of urban population)  \
# 0                                                94.78
# 1                                                65.83
# 2                                                76.24
# 3                                                94.35
# 4                                                76.15
# ..                                                 ...
# 589                                              89.06
# 590                                              99.70
# 591                                              75.11
# 592                                              83.86
# 593                                              94.00
#
#      People using at least basic sanitation services (% of population)  \
# 0                                                85.85
# 1                                                37.26
# 2                                                11.80
# 3                                                61.60
# 4                                                15.60
# ..                                                 ...
# 589                                              16.13
# 590                                              90.92
# 591                                              18.47
# 592                                              26.37
# 593                                              36.22
#
#      People using at least basic sanitation services, rural (% of rural population)  \
# 0                                                76.94
# 1                                                14.00
# 2                                                 4.29
# 3                                                39.99
# 4                                                 6.38
# ..                                                 ...
# 589                                               7.40
# 590                                              81.35
# 591                                              16.17
# 592                                              18.93
# 593                                              31.47
#
#      People using at least basic sanitation services, urban  (% of urban population)  \
# 0                                                90.57
# 1                                                54.44
# 2                                                22.36
# 3                                                77.30
# 4                                                46.49
# ..                                                 ...
# 589                                              28.61
# 590                                              95.29
# 591                                              26.11
# 592                                              36.24
# 593                                              46.22
#
#       latitude  longitude                            geometry
# 0    28.033886   1.659626          POINT (28.033886 1.659626)
# 1   -11.202692  17.873887        POINT (-11.202692 17.873887)
# 2     9.307690   2.315834  POINT (9.307689999999999 2.315834)
# 3   -22.328474  24.684866        POINT (-22.328474 24.684866)
# 4    12.238333  -1.561593         POINT (12.238333 -1.561593)
# ..         ...        ...                                 ...
# 589   8.619543   0.824782           POINT (8.619543 0.824782)
# 590  33.886917   9.537499          POINT (33.886917 9.537499)
# 591   1.373333  32.290275          POINT (1.373333 32.290275)
# 592 -13.133897  27.849332        POINT (-13.133897 27.849332)
# 593 -19.015438  29.154857        POINT (-19.015438 29.154857)
#
# [585 rows x 27 columns]

# %% [markdown]
# #### Checking for duplicate rows

# %%
malaria_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Make a copy of the DataFrame for cleaning

# %%
clean_df = malaria_df.copy()

# %% [markdown]
# #### Filling the missing values with 'Unknown'

# %%
clean_df =clean_df.fillna('Unknown')
clean_df
# Out:
#      Country Name  Year Country Code  \
# 0         Algeria  2007          DZA
# 1          Angola  2007          AGO
# 2           Benin  2007          BEN
# 3        Botswana  2007          BWA
# 4    Burkina Faso  2007          BFA
# ..            ...   ...          ...
# 589          Togo  2017          TGO
# 590       Tunisia  2017          TUN
# 591        Uganda  2017          UGA
# 592        Zambia  2017          ZMB
# 593      Zimbabwe  2017          ZWE
#
#     Incidence of malaria (per 1,000 population at risk)  \
# 0                                                 0.01
# 1                                               286.72
# 2                                               480.24
# 3                                                 1.03
# 4                                                503.8
# ..                                                 ...
# 589                                              278.2
# 590                                            Unknown
# 591                                             336.76
# 592                                             160.05
# 593                                             108.55
#
#     Malaria cases reported  \
# 0                     26.0
# 1                1533485.0
# 2                      0.0
# 3                    390.0
# 4                  44246.0
# ..                     ...
# 589              1755577.0
# 590                Unknown
# 591             11667831.0
# 592              5505639.0
# 593               467508.0
#
#     Use of insecticide-treated bed nets (% of under-5 population)  \
# 0                                              Unknown
# 1                                                 18.0
# 2                                              Unknown
# 3                                              Unknown
# 4                                              Unknown
# ..                                                 ...
# 589                                               69.7
# 590                                            Unknown
# 591                                            Unknown
# 592                                            Unknown
# 593                                            Unknown
#
#     Children with fever receiving antimalarial drugs (% of children under age 5 with fever)  \
# 0                                              Unknown
# 1                                                 29.8
# 2                                              Unknown
# 3                                              Unknown
# 4                                              Unknown
# ..                                                 ...
# 589                                               31.1
# 590                                            Unknown
# 591                                            Unknown
# 592                                            Unknown
# 593                                            Unknown
#
#     Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)  \
# 0                                              Unknown
# 1                                                  1.5
# 2                                              Unknown
# 3                                              Unknown
# 4                                              Unknown
# ..                                                 ...
# 589                                               41.7
# 590                                            Unknown
# 591                                            Unknown
# 592                                            Unknown
# 593                                            Unknown
#
#     People using safely managed drinking water services (% of population)  \
# 0                                              Unknown
# 1                                              Unknown
# 2                                              Unknown
# 3                                              Unknown
# 4                                              Unknown
# ..                                                 ...
# 589                                            Unknown
# 590                                              92.66
# 591                                               7.07
# 592                                            Unknown
# 593                                            Unknown
#
#     People using safely managed drinking water services, rural (% of rural population)  \
# 0                                              Unknown
# 1                                              Unknown
# 2                                              Unknown
# 3                                              Unknown
# 4                                              Unknown
# ..                                                 ...
# 589                                            Unknown
# 590                                            Unknown
# 591                                               4.46
# 592                                            Unknown
# 593                                            Unknown
#
#      ... Urban population growth (annual %)  \
# 0    ...                               2.71
# 1    ...                               5.01
# 2    ...                               4.09
# 3    ...                                4.8
# 4    ...                               5.91
# ..   ...                                ...
# 589  ...                               3.79
# 590  ...                               1.57
# 591  ...                               6.25
# 592  ...                               4.21
# 593  ...                               1.28
#
#     People using at least basic drinking water services (% of population)  \
# 0                                                91.68
# 1                                                47.96
# 2                                                63.78
# 3                                                78.89
# 4                                                52.27
# ..                                                 ...
# 589                                              65.13
# 590                                              96.25
# 591                                               49.1
# 592                                              59.96
# 593                                              64.05
#
#     People using at least basic drinking water services, rural (% of rural population)  \
# 0                                                85.83
# 1                                                23.77
# 2                                                54.92
# 3                                                 57.6
# 4                                                45.13
# ..                                                 ...
# 589                                              48.39
# 590                                              88.71
# 591                                              41.25
# 592                                              41.95
# 593                                               49.8
#
#     People using at least basic drinking water services, urban (% of urban population)  \
# 0                                                94.78
# 1                                                65.83
# 2                                                76.24
# 3                                                94.35
# 4                                                76.15
# ..                                                 ...
# 589                                              89.06
# 590                                               99.7
# 591                                              75.11
# 592                                              83.86
# 593                                               94.0
#
#     People using at least basic sanitation services (% of population)  \
# 0                                                85.85
# 1                                                37.26
# 2                                                 11.8
# 3                                                 61.6
# 4                                                 15.6
# ..                                                 ...
# 589                                              16.13
# 590                                              90.92
# 591                                              18.47
# 592                                              26.37
# 593                                              36.22
#
#     People using at least basic sanitation services, rural (% of rural population)  \
# 0                                                76.94
# 1                                                 14.0
# 2                                                 4.29
# 3                                                39.99
# 4                                                 6.38
# ..                                                 ...
# 589                                                7.4
# 590                                              81.35
# 591                                              16.17
# 592                                              18.93
# 593                                              31.47
#
#     People using at least basic sanitation services, urban  (% of urban population)  \
# 0                                                90.57
# 1                                                54.44
# 2                                                22.36
# 3                                                 77.3
# 4                                                46.49
# ..                                                 ...
# 589                                              28.61
# 590                                              95.29
# 591                                              26.11
# 592                                              36.24
# 593                                              46.22
#
#       latitude  longitude                            geometry
# 0    28.033886   1.659626          POINT (28.033886 1.659626)
# 1   -11.202692  17.873887        POINT (-11.202692 17.873887)
# 2     9.307690   2.315834  POINT (9.307689999999999 2.315834)
# 3   -22.328474  24.684866        POINT (-22.328474 24.684866)
# 4    12.238333  -1.561593         POINT (12.238333 -1.561593)
# ..         ...        ...                                 ...
# 589   8.619543   0.824782           POINT (8.619543 0.824782)
# 590  33.886917   9.537499          POINT (33.886917 9.537499)
# 591   1.373333  32.290275          POINT (1.373333 32.290275)
# 592 -13.133897  27.849332        POINT (-13.133897 27.849332)
# 593 -19.015438  29.154857        POINT (-19.015438 29.154857)
#
# [594 rows x 27 columns]

# %% [markdown]
# #### Cross-checking for missing values in the columns after filling

# %%
clean_df.isnull().sum()
# Out:
# Country Name                                                                               0
# Year                                                                                       0
# Country Code                                                                               0
# Incidence of malaria (per 1,000 population at risk)                                        0
# Malaria cases reported                                                                     0
# Use of insecticide-treated bed nets (% of under-5 population)                              0
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever)    0
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)      0
# People using safely managed drinking water services (% of population)                      0
# People using safely managed drinking water services, rural (% of rural population)         0
# People using safely managed drinking water services, urban (% of urban population)         0
# People using safely managed sanitation services (% of population)                          0
# People using safely managed sanitation services, rural (% of rural population)             0
# People using safely managed sanitation services, urban  (% of urban population)            0
# Rural population (% of total population)                                                   0
# Rural population growth (annual %)                                                         0
# Urban population (% of total population)                                                   0
# Urban population growth (annual %)                                                         0
# People using at least basic drinking water services (% of population)                      0
# People using at least basic drinking water services, rural (% of rural population)         0
# People using at least basic drinking water services, urban (% of urban population)         0
# People using at least basic sanitation services (% of population)                          0
# People using at least basic sanitation services, rural (% of rural population)             0
# People using at least basic sanitation services, urban  (% of urban population)            0
# latitude                                                                                   0
# longitude                                                                                  0
# geometry                                                                                   0
# dtype: int64

# %% [markdown]
# ## QUESTIONS | ANALYSIS

# %% [markdown]
# #### 1.What is the overall trend of malaria incidence across African countries over time

# %%
# Convert the column to floats, handling non-numeric values by coercing them to NaN
clean_df['Incidence of malaria (per 1,000 population at risk)'] = \
pd.to_numeric(clean_df['Incidence of malaria (per 1,000 population at risk)'], errors='coerce')

# %%
# Group by 'Year' and calculate the mean incidence of malaria
malaria_trend = clean_df.groupby('Year')['Incidence of malaria (per 1,000 population at risk)'].mean()
print(f"Overall trend of malaria incidence: {malaria_trend}")
# Out:
# Overall trend of malaria incidence: Year
# 2007    210.1678
# 2008    204.2538
# 2009    202.7910
# 2010    199.0768
# 2011    191.6636
# 2012    189.2054
# 2013    185.1222
# 2014    176.7384
# 2015    176.7422
# 2016    178.8848
# 2017    176.3164
# Name: Incidence of malaria (per 1,000 population at risk), dtype: float64

# %% [markdown]
# #### 2.Which African country reported the highest number of malaria cases in a given year?

# %%
# Convert the 'Malaria cases reported' column to floats, handling non-numeric values
clean_df['Malaria cases reported'] = pd.to_numeric(clean_df['Malaria cases reported'], errors='coerce')

# %%
max_malaria_cases = clean_df[clean_df['Malaria cases reported'] == clean_df['Malaria cases reported'].max()]
max_malaria_cases
# Out:
#          Country Name  Year Country Code  \
# 497  Congo, Dem. Rep.  2016          COD
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 497                                             322.77
#
#      Malaria cases reported  \
# 497              16821130.0
#
#     Use of insecticide-treated bed nets (% of under-5 population)  \
# 497                                            Unknown
#
#     Children with fever receiving antimalarial drugs (% of children under age 5 with fever)  \
# 497                                            Unknown
#
#     Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)  \
# 497                                            Unknown
#
#     People using safely managed drinking water services (% of population)  \
# 497                                            Unknown
#
#     People using safely managed drinking water services, rural (% of rural population)  \
# 497                                            Unknown
#
#      ... Urban population growth (annual %)  \
# 497  ...                                4.6
#
#     People using at least basic drinking water services (% of population)  \
# 497                                              42.98
#
#     People using at least basic drinking water services, rural (% of rural population)  \
# 497                                              22.83
#
#     People using at least basic drinking water services, urban (% of urban population)  \
# 497                                              69.35
#
#     People using at least basic sanitation services (% of population)  \
# 497                                              20.43
#
#     People using at least basic sanitation services, rural (% of rural population)  \
# 497                                              18.17
#
#     People using at least basic sanitation services, urban  (% of urban population)  \
# 497                                              23.38
#
#      latitude  longitude                     geometry
# 497 -4.038333  21.758664  POINT (-4.038333 21.758664)
#
# [1 rows x 27 columns]

# %% [markdown]
# #### 3.What are the top 5 African countries with the highest Malaria Incidence?

# %%
clean_df["Incidence of malaria (per 1,000 population at risk)"] = \
pd.to_numeric(clean_df["Incidence of malaria (per 1,000 population at risk)"], errors='coerce')

# %%
country_incidence = clean_df.groupby("Country Name")["Incidence of malaria (per 1,000 population at risk)"].mean()
top_5_countries = country_incidence.nlargest(5)
top_5_countries
# Out:
# Country Name
# Burkina Faso                484.809091
# Sierra Leone                417.908182
# Central African Republic    412.490909
# Benin                       410.406364
# Cote d'Ivoire               410.290909
# Name: Incidence of malaria (per 1,000 population at risk), dtype: float64

# %%
clean_df
# Out:
#      Country Name  Year Country Code  \
# 0         Algeria  2007          DZA
# 1          Angola  2007          AGO
# 2           Benin  2007          BEN
# 3        Botswana  2007          BWA
# 4    Burkina Faso  2007          BFA
# ..            ...   ...          ...
# 589          Togo  2017          TGO
# 590       Tunisia  2017          TUN
# 591        Uganda  2017          UGA
# 592        Zambia  2017          ZMB
# 593      Zimbabwe  2017          ZWE
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 0                                                 0.01
# 1                                               286.72
# 2                                               480.24
# 3                                                 1.03
# 4                                               503.80
# ..                                                 ...
# 589                                             278.20
# 590                                                NaN
# 591                                             336.76
# 592                                             160.05
# 593                                             108.55
#
#      Malaria cases reported  \
# 0                      26.0
# 1                 1533485.0
# 2                       0.0
# 3                     390.0
# 4                   44246.0
# ..                      ...
# 589               1755577.0
# 590                     NaN
# 591              11667831.0
# 592               5505639.0
# 593                467508.0
#
#     Use of insecticide-treated bed nets (% of under-5 population)  \
# 0                                              Unknown
# 1                                                 18.0
# 2                                              Unknown
# 3                                              Unknown
# 4                                              Unknown
# ..                                                 ...
# 589                                               69.7
# 590                                            Unknown
# 591                                            Unknown
# 592                                            Unknown
# 593                                            Unknown
#
#     Children with fever receiving antimalarial drugs (% of children under age 5 with fever)  \
# 0                                              Unknown
# 1                                                 29.8
# 2                                              Unknown
# 3                                              Unknown
# 4                                              Unknown
# ..                                                 ...
# 589                                               31.1
# 590                                            Unknown
# 591                                            Unknown
# 592                                            Unknown
# 593                                            Unknown
#
#     Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)  \
# 0                                              Unknown
# 1                                                  1.5
# 2                                              Unknown
# 3                                              Unknown
# 4                                              Unknown
# ..                                                 ...
# 589                                               41.7
# 590                                            Unknown
# 591                                            Unknown
# 592                                            Unknown
# 593                                            Unknown
#
#     People using safely managed drinking water services (% of population)  \
# 0                                              Unknown
# 1                                              Unknown
# 2                                              Unknown
# 3                                              Unknown
# 4                                              Unknown
# ..                                                 ...
# 589                                            Unknown
# 590                                              92.66
# 591                                               7.07
# 592                                            Unknown
# 593                                            Unknown
#
#     People using safely managed drinking water services, rural (% of rural population)  \
# 0                                              Unknown
# 1                                              Unknown
# 2                                              Unknown
# 3                                              Unknown
# 4                                              Unknown
# ..                                                 ...
# 589                                            Unknown
# 590                                            Unknown
# 591                                               4.46
# 592                                            Unknown
# 593                                            Unknown
#
#      ... Urban population growth (annual %)  \
# 0    ...                               2.71
# 1    ...                               5.01
# 2    ...                               4.09
# 3    ...                                4.8
# 4    ...                               5.91
# ..   ...                                ...
# 589  ...                               3.79
# 590  ...                               1.57
# 591  ...                               6.25
# 592  ...                               4.21
# 593  ...                               1.28
#
#     People using at least basic drinking water services (% of population)  \
# 0                                                91.68
# 1                                                47.96
# 2                                                63.78
# 3                                                78.89
# 4                                                52.27
# ..                                                 ...
# 589                                              65.13
# 590                                              96.25
# 591                                               49.1
# 592                                              59.96
# 593                                              64.05
#
#     People using at least basic drinking water services, rural (% of rural population)  \
# 0                                                85.83
# 1                                                23.77
# 2                                                54.92
# 3                                                 57.6
# 4                                                45.13
# ..                                                 ...
# 589                                              48.39
# 590                                              88.71
# 591                                              41.25
# 592                                              41.95
# 593                                               49.8
#
#     People using at least basic drinking water services, urban (% of urban population)  \
# 0                                                94.78
# 1                                                65.83
# 2                                                76.24
# 3                                                94.35
# 4                                                76.15
# ..                                                 ...
# 589                                              89.06
# 590                                               99.7
# 591                                              75.11
# 592                                              83.86
# 593                                               94.0
#
#     People using at least basic sanitation services (% of population)  \
# 0                                                85.85
# 1                                                37.26
# 2                                                 11.8
# 3                                                 61.6
# 4                                                 15.6
# ..                                                 ...
# 589                                              16.13
# 590                                              90.92
# 591                                              18.47
# 592                                              26.37
# 593                                              36.22
#
#     People using at least basic sanitation services, rural (% of rural population)  \
# 0                                                76.94
# 1                                                 14.0
# 2                                                 4.29
# 3                                                39.99
# 4                                                 6.38
# ..                                                 ...
# 589                                                7.4
# 590                                              81.35
# 591                                              16.17
# 592                                              18.93
# 593                                              31.47
#
#     People using at least basic sanitation services, urban  (% of urban population)  \
# 0                                                90.57
# 1                                                54.44
# 2                                                22.36
# 3                                                 77.3
# 4                                                46.49
# ..                                                 ...
# 589                                              28.61
# 590                                              95.29
# 591                                              26.11
# 592                                              36.24
# 593                                              46.22
#
#       latitude  longitude                            geometry
# 0    28.033886   1.659626          POINT (28.033886 1.659626)
# 1   -11.202692  17.873887        POINT (-11.202692 17.873887)
# 2     9.307690   2.315834  POINT (9.307689999999999 2.315834)
# 3   -22.328474  24.684866        POINT (-22.328474 24.684866)
# 4    12.238333  -1.561593         POINT (12.238333 -1.561593)
# ..         ...        ...                                 ...
# 589   8.619543   0.824782           POINT (8.619543 0.824782)
# 590  33.886917   9.537499          POINT (33.886917 9.537499)
# 591   1.373333  32.290275          POINT (1.373333 32.290275)
# 592 -13.133897  27.849332        POINT (-13.133897 27.849332)
# 593 -19.015438  29.154857        POINT (-19.015438 29.154857)
#
# [594 rows x 27 columns]

# %% [markdown]
# #### 4.Which year had the highest global average malaria incidence?

# %%
highest_incidence_year = clean_df.groupby('Year')['Incidence of malaria (per 1,000 population at risk)'].mean().idxmax()
highest_incidence_year
# Out:
# np.int64(2007)

# %% [markdown]
# #### 5.What is the correlation between the use of insecticide-treated bed nets and malaria incidence?

# %%
# Convert the 'Use of insecticide-treated bed nets' column to floats, handling non-numeric values
clean_df['Use of insecticide-treated bed nets (% of under-5 population)'] = \
pd.to_numeric(clean_df['Use of insecticide-treated bed nets (% of under-5 population)'], errors='coerce')

# %%
correlation = clean_df['Use of insecticide-treated bed nets (% of under-5 population)'].corr(
              clean_df['Incidence of malaria (per 1,000 population at risk)'])
correlation
# Out:
# np.float64(0.009607885214414188)

# %% [markdown]
# #### 6.Which African country shows the most improvement in rural sanitation services over time?

# %%
# Convert the 'People using safely managed sanitation services, rural' column to floats, handling non-numeric values
clean_df['People using safely managed sanitation services, rural (% of rural population)'] = \
pd.to_numeric(clean_df['People using safely managed sanitation services, rural (% of rural population)'], errors='coerce')

# %%
# Calculate the difference in sanitation services year-over-year for each country
clean_df['Sanitation Improvement'] = clean_df.groupby('Country Name')\
['People using safely managed sanitation services, rural (% of rural population)'].diff()

most_improved_country = clean_df.groupby('Country Name')['Sanitation Improvement'].sum().idxmax()
most_improved_country
# Out:
# 'Mali'

# %% [markdown]
# #### 7.What percentage of the population is Rural vs. Urban in the top 10 countries with the most malaria cases?

# %%
# Identify the top 10 countries with the most malaria cases
top_10_malaria_countries = clean_df.groupby('Country Name')['Malaria cases reported'].sum().nlargest(10).index

# Filter data for these countries and select relevant columns
rural_urban_split = clean_df[clean_df['Country Name'].isin(top_10_malaria_countries)]\
[['Country Name', 'Rural population (% of total population)', 'Urban population (% of total population)']]

rural_urban_split
# Out:
#          Country Name Rural population (% of total population)  \
# 1              Angola                                    42.48
# 4        Burkina Faso                                     77.0
# 5             Burundi                                    90.14
# 11   Congo, Dem. Rep.                                    61.53
# 22              Ghana                                    51.33
# ..                ...                                      ...
# 570            Malawi                                    83.29
# 575        Mozambique                                    64.55
# 578           Nigeria                                    50.48
# 588          Tanzania                                    66.95
# 591            Uganda                                     76.8
#
#     Urban population (% of total population)
# 1                                      57.52
# 4                                       23.0
# 5                                       9.86
# 11                                     38.47
# 22                                     48.67
# ..                                       ...
# 570                                    16.71
# 575                                    35.46
# 578                                    49.52
# 588                                    33.05
# 591                                     23.2
#
# [110 rows x 3 columns]

# %% [markdown]
# ## Analysis on Ghana

# %% [markdown]
# #### Filtering the dataset for Ghana.

# %%
ghana_df=clean_df[clean_df['Country Name']=='Ghana']
ghana_df
# Out:
#     Country Name  Year Country Code  \
# 22         Ghana  2007          GHA
# 76         Ghana  2008          GHA
# 130        Ghana  2009          GHA
# 184        Ghana  2010          GHA
# 238        Ghana  2011          GHA
# 292        Ghana  2012          GHA
# 346        Ghana  2013          GHA
# 400        Ghana  2014          GHA
# 454        Ghana  2015          GHA
# 508        Ghana  2016          GHA
# 562        Ghana  2017          GHA
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 22                                              322.33
# 76                                              333.72
# 130                                             351.39
# 184                                             364.15
# 238                                             379.52
# 292                                             374.29
# 346                                             349.28
# 400                                             315.76
# 454                                             277.19
# 508                                             236.00
# 562                                             212.56
#
#      Malaria cases reported  \
# 22                 476484.0
# 76                1094483.0
# 130               1104370.0
# 184               1071637.0
# 238               1041260.0
# 292               3755166.0
# 346               1639451.0
# 400               3415912.0
# 454               4319919.0
# 508               4505442.0
# 562               5584185.0
#
#      Use of insecticide-treated bed nets (% of under-5 population)  \
# 22                                                 NaN
# 76                                                28.0
# 130                                                NaN
# 184                                                NaN
# 238                                               39.0
# 292                                                NaN
# 346                                                NaN
# 400                                               46.6
# 454                                                NaN
# 508                                               52.2
# 562                                                NaN
#
#     Children with fever receiving antimalarial drugs (% of children under age 5 with fever)  \
# 22                                             Unknown
# 76                                                43.0
# 130                                            Unknown
# 184                                            Unknown
# 238                                               52.6
# 292                                            Unknown
# 346                                            Unknown
# 400                                               48.5
# 454                                            Unknown
# 508                                               50.1
# 562                                            Unknown
#
#     Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)  \
# 22                                             Unknown
# 76                                                28.0
# 130                                            Unknown
# 184                                            Unknown
# 238                                          39.388704
# 292                                            Unknown
# 346                                            Unknown
# 400                                               38.6
# 454                                            Unknown
# 508                                               59.6
# 562                                            Unknown
#
#     People using safely managed drinking water services (% of population)  \
# 22                                                21.1
# 76                                                22.5
# 130                                              23.93
# 184                                              25.39
# 238                                              26.87
# 292                                              28.39
# 346                                              29.94
# 400                                              31.52
# 454                                              33.12
# 508                                              34.75
# 562                                              36.41
#
#     People using safely managed drinking water services, rural (% of rural population)  \
# 22                                                3.86
# 76                                                4.54
# 130                                               5.23
# 184                                               5.94
# 238                                               6.67
# 292                                               7.42
# 346                                               8.19
# 400                                               8.98
# 454                                               9.78
# 508                                              10.61
# 562                                              11.45
#
#      ...  \
# 22   ...
# 76   ...
# 130  ...
# 184  ...
# 238  ...
# 292  ...
# 346  ...
# 400  ...
# 454  ...
# 508  ...
# 562  ...
#
#     People using at least basic drinking water services (% of population)  \
# 22                                               71.35
# 76                                               72.35
# 130                                              73.36
# 184                                              74.36
# 238                                              75.37
# 292                                              76.38
# 346                                              77.39
# 400                                              78.41
# 454                                              79.42
# 508                                              80.44
# 562                                              81.45
#
#     People using at least basic drinking water services, rural (% of rural population)  \
# 22                                               59.83
# 76                                               60.62
# 130                                              61.41
# 184                                              62.19
# 238                                              62.97
# 292                                              63.74
# 346                                              64.51
# 400                                              65.28
# 454                                              66.04
# 508                                              66.79
# 562                                              67.54
#
#      People using at least basic drinking water services, urban (% of urban population)  \
# 22                                                83.5
# 76                                               84.39
# 130                                              85.29
# 184                                              86.19
# 238                                               87.1
# 292                                              88.01
# 346                                              88.93
# 400                                              89.85
# 454                                              90.78
# 508                                              91.71
# 562                                              92.65
#
#     People using at least basic sanitation services (% of population)  \
# 22                                               12.12
# 76                                               12.72
# 130                                              13.33
# 184                                              13.95
# 238                                              14.57
# 292                                              15.21
# 346                                              15.85
# 400                                              16.49
# 454                                              17.15
# 508                                              17.81
# 562                                              18.47
#
#     People using at least basic sanitation services, rural (% of rural population)  \
# 22                                                6.94
# 76                                                 7.4
# 130                                               7.87
# 184                                               8.34
# 238                                               8.83
# 292                                               9.33
# 346                                               9.83
# 400                                              10.34
# 454                                              10.86
# 508                                              11.39
# 562                                              11.93
#
#     People using at least basic sanitation services, urban  (% of urban population)  \
# 22                                               17.58
# 76                                               18.18
# 130                                              18.79
# 184                                              19.39
# 238                                               20.0
# 292                                              20.62
# 346                                              21.24
# 400                                              21.86
# 454                                              22.48
# 508                                              23.11
# 562                                              23.74
#
#      latitude longitude                    geometry Sanitation Improvement
# 22   7.946527 -1.023194  POINT (7.946527 -1.023194)                    NaN
# 76   7.946527 -1.023194  POINT (7.946527 -1.023194)                    NaN
# 130  7.946527 -1.023194  POINT (7.946527 -1.023194)                    NaN
# 184  7.946527 -1.023194  POINT (7.946527 -1.023194)                    NaN
# 238  7.946527 -1.023194  POINT (7.946527 -1.023194)                    NaN
# 292  7.946527 -1.023194  POINT (7.946527 -1.023194)                    NaN
# 346  7.946527 -1.023194  POINT (7.946527 -1.023194)                    NaN
# 400  7.946527 -1.023194  POINT (7.946527 -1.023194)                    NaN
# 454  7.946527 -1.023194  POINT (7.946527 -1.023194)                    NaN
# 508  7.946527 -1.023194  POINT (7.946527 -1.023194)                    NaN
# 562  7.946527 -1.023194  POINT (7.946527 -1.023194)                    NaN
#
# [11 rows x 28 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Cross-checking the missing columns for Ghana

# %%
ghana_df.isnull().sum()
# Out:
# Country Name                                                                                0
# Year                                                                                        0
# Country Code                                                                                0
# Incidence of malaria (per 1,000 population at risk)                                         0
# Malaria cases reported                                                                      0
# Use of insecticide-treated bed nets (% of under-5 population)                               7
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever)     0
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)       0
# People using safely managed drinking water services (% of population)                       0
# People using safely managed drinking water services, rural (% of rural population)          0
# People using safely managed drinking water services, urban (% of urban population)          0
# People using safely managed sanitation services (% of population)                           0
# People using safely managed sanitation services, rural (% of rural population)             11
# People using safely managed sanitation services, urban  (% of urban population)             0
# Rural population (% of total population)                                                    0
# Rural population growth (annual %)                                                          0
# Urban population (% of total population)                                                    0
# Urban population growth (annual %)                                                          0
# People using at least basic drinking water services (% of population)                       0
# People using at least basic drinking water services, rural (% of rural population)          0
# People using at least basic drinking water services, urban (% of urban population)          0
# People using at least basic sanitation services (% of population)                           0
# People using at least basic sanitation services, rural (% of rural population)              0
# People using at least basic sanitation services, urban  (% of urban population)             0
# latitude                                                                                    0
# longitude                                                                                   0
# geometry                                                                                    0
# Sanitation Improvement                                                                     11
# dtype: int64

# %% [markdown]
# #### Filling missing values with 'Unknown' for Ghana

# %%
ghana_df=ghana_df.fillna('Unknown')
ghana_df
# Out:
#     Country Name  Year Country Code  \
# 22         Ghana  2007          GHA
# 76         Ghana  2008          GHA
# 130        Ghana  2009          GHA
# 184        Ghana  2010          GHA
# 238        Ghana  2011          GHA
# 292        Ghana  2012          GHA
# 346        Ghana  2013          GHA
# 400        Ghana  2014          GHA
# 454        Ghana  2015          GHA
# 508        Ghana  2016          GHA
# 562        Ghana  2017          GHA
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 22                                              322.33
# 76                                              333.72
# 130                                             351.39
# 184                                             364.15
# 238                                             379.52
# 292                                             374.29
# 346                                             349.28
# 400                                             315.76
# 454                                             277.19
# 508                                             236.00
# 562                                             212.56
#
#      Malaria cases reported  \
# 22                 476484.0
# 76                1094483.0
# 130               1104370.0
# 184               1071637.0
# 238               1041260.0
# 292               3755166.0
# 346               1639451.0
# 400               3415912.0
# 454               4319919.0
# 508               4505442.0
# 562               5584185.0
#
#     Use of insecticide-treated bed nets (% of under-5 population)  \
# 22                                             Unknown
# 76                                                28.0
# 130                                            Unknown
# 184                                            Unknown
# 238                                               39.0
# 292                                            Unknown
# 346                                            Unknown
# 400                                               46.6
# 454                                            Unknown
# 508                                               52.2
# 562                                            Unknown
#
#     Children with fever receiving antimalarial drugs (% of children under age 5 with fever)  \
# 22                                             Unknown
# 76                                                43.0
# 130                                            Unknown
# 184                                            Unknown
# 238                                               52.6
# 292                                            Unknown
# 346                                            Unknown
# 400                                               48.5
# 454                                            Unknown
# 508                                               50.1
# 562                                            Unknown
#
#     Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)  \
# 22                                             Unknown
# 76                                                28.0
# 130                                            Unknown
# 184                                            Unknown
# 238                                          39.388704
# 292                                            Unknown
# 346                                            Unknown
# 400                                               38.6
# 454                                            Unknown
# 508                                               59.6
# 562                                            Unknown
#
#      People using safely managed drinking water services (% of population)  \
# 22                                               21.10
# 76                                               22.50
# 130                                              23.93
# 184                                              25.39
# 238                                              26.87
# 292                                              28.39
# 346                                              29.94
# 400                                              31.52
# 454                                              33.12
# 508                                              34.75
# 562                                              36.41
#
#      People using safely managed drinking water services, rural (% of rural population)  \
# 22                                                3.86
# 76                                                4.54
# 130                                               5.23
# 184                                               5.94
# 238                                               6.67
# 292                                               7.42
# 346                                               8.19
# 400                                               8.98
# 454                                               9.78
# 508                                              10.61
# 562                                              11.45
#
#      ...  \
# 22   ...
# 76   ...
# 130  ...
# 184  ...
# 238  ...
# 292  ...
# 346  ...
# 400  ...
# 454  ...
# 508  ...
# 562  ...
#
#      People using at least basic drinking water services (% of population)  \
# 22                                               71.35
# 76                                               72.35
# 130                                              73.36
# 184                                              74.36
# 238                                              75.37
# 292                                              76.38
# 346                                              77.39
# 400                                              78.41
# 454                                              79.42
# 508                                              80.44
# 562                                              81.45
#
#     People using at least basic drinking water services, rural (% of rural population)  \
# 22                                               59.83
# 76                                               60.62
# 130                                              61.41
# 184                                              62.19
# 238                                              62.97
# 292                                              63.74
# 346                                              64.51
# 400                                              65.28
# 454                                              66.04
# 508                                              66.79
# 562                                              67.54
#
#     People using at least basic drinking water services, urban (% of urban population)  \
# 22                                               83.50
# 76                                               84.39
# 130                                              85.29
# 184                                              86.19
# 238                                              87.10
# 292                                              88.01
# 346                                              88.93
# 400                                              89.85
# 454                                              90.78
# 508                                              91.71
# 562                                              92.65
#
#     People using at least basic sanitation services (% of population)  \
# 22                                               12.12
# 76                                               12.72
# 130                                              13.33
# 184                                              13.95
# 238                                              14.57
# 292                                              15.21
# 346                                              15.85
# 400                                              16.49
# 454                                              17.15
# 508                                              17.81
# 562                                              18.47
#
#      People using at least basic sanitation services, rural (% of rural population)  \
# 22                                                6.94
# 76                                                7.40
# 130                                               7.87
# 184                                               8.34
# 238                                               8.83
# 292                                               9.33
# 346                                               9.83
# 400                                              10.34
# 454                                              10.86
# 508                                              11.39
# 562                                              11.93
#
#      People using at least basic sanitation services, urban  (% of urban population)  \
# 22                                               17.58
# 76                                               18.18
# 130                                              18.79
# 184                                              19.39
# 238                                              20.00
# 292                                              20.62
# 346                                              21.24
# 400                                              21.86
# 454                                              22.48
# 508                                              23.11
# 562                                              23.74
#
#      latitude  longitude                    geometry  Sanitation Improvement
# 22   7.946527  -1.023194  POINT (7.946527 -1.023194)                 Unknown
# 76   7.946527  -1.023194  POINT (7.946527 -1.023194)                 Unknown
# 130  7.946527  -1.023194  POINT (7.946527 -1.023194)                 Unknown
# 184  7.946527  -1.023194  POINT (7.946527 -1.023194)                 Unknown
# 238  7.946527  -1.023194  POINT (7.946527 -1.023194)                 Unknown
# 292  7.946527  -1.023194  POINT (7.946527 -1.023194)                 Unknown
# 346  7.946527  -1.023194  POINT (7.946527 -1.023194)                 Unknown
# 400  7.946527  -1.023194  POINT (7.946527 -1.023194)                 Unknown
# 454  7.946527  -1.023194  POINT (7.946527 -1.023194)                 Unknown
# 508  7.946527  -1.023194  POINT (7.946527 -1.023194)                 Unknown
# 562  7.946527  -1.023194  POINT (7.946527 -1.023194)                 Unknown
#
# [11 rows x 28 columns]

# %% [markdown]
# #### Confirming missing values after filling

# %%
ghana_df.isnull().sum()
# Out:
# Country Name                                                                               0
# Year                                                                                       0
# Country Code                                                                               0
# Incidence of malaria (per 1,000 population at risk)                                        0
# Malaria cases reported                                                                     0
# Use of insecticide-treated bed nets (% of under-5 population)                              0
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever)    0
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)      0
# People using safely managed drinking water services (% of population)                      0
# People using safely managed drinking water services, rural (% of rural population)         0
# People using safely managed drinking water services, urban (% of urban population)         0
# People using safely managed sanitation services (% of population)                          0
# People using safely managed sanitation services, rural (% of rural population)             0
# People using safely managed sanitation services, urban  (% of urban population)            0
# Rural population (% of total population)                                                   0
# Rural population growth (annual %)                                                         0
# Urban population (% of total population)                                                   0
# Urban population growth (annual %)                                                         0
# People using at least basic drinking water services (% of population)                      0
# People using at least basic drinking water services, rural (% of rural population)         0
# People using at least basic drinking water services, urban (% of urban population)         0
# People using at least basic sanitation services (% of population)                          0
# People using at least basic sanitation services, rural (% of rural population)             0
# People using at least basic sanitation services, urban  (% of urban population)            0
# latitude                                                                                   0
# longitude                                                                                  0
# geometry                                                                                   0
# Sanitation Improvement                                                                     0
# dtype: int64

# %% [markdown]
# ## QUESTIONS | ANALYSIS IN GHANA
# #### 1.What is the trend of malaria incidence in Ghana over the years?

# %%
malaria_trend = ghana_df[['Year', 'Incidence of malaria (per 1,000 population at risk)']]
malaria_trend
# Out:
#      Year  Incidence of malaria (per 1,000 population at risk)
# 22   2007                                             322.33
# 76   2008                                             333.72
# 130  2009                                             351.39
# 184  2010                                             364.15
# 238  2011                                             379.52
# 292  2012                                             374.29
# 346  2013                                             349.28
# 400  2014                                             315.76
# 454  2015                                             277.19
# 508  2016                                             236.00
# 562  2017                                             212.56

# %% [markdown]
# #### 2.How has the number of malaria cases reported in Ghana changed over time?

# %%
malaria_cases_trend = ghana_df[['Year', 'Malaria cases reported']]
malaria_cases_trend
# Out:
#      Year  Malaria cases reported
# 22   2007                476484.0
# 76   2008               1094483.0
# 130  2009               1104370.0
# 184  2010               1071637.0
# 238  2011               1041260.0
# 292  2012               3755166.0
# 346  2013               1639451.0
# 400  2014               3415912.0
# 454  2015               4319919.0
# 508  2016               4505442.0
# 562  2017               5584185.0

# %% [markdown]
# #### 3. What is the correlation between the use of insecticide-treated bed nets and malaria incidence in Ghana?

# %%
# Convert Non-Numeric Values to NaN
ghana_df['Use of insecticide-treated bed nets (% of under-5 population)'] = \
pd.to_numeric(ghana_df['Use of insecticide-treated bed nets (% of under-5 population)'], errors='coerce')

ghana_df['Incidence of malaria (per 1,000 population at risk)'] = \
pd.to_numeric(ghana_df['Incidence of malaria (per 1,000 population at risk)'], errors='coerce')

# %%
bed_net_correlation = ghana_df['Use of insecticide-treated bed nets (% of under-5 population)'].corr(\
                      ghana_df['Incidence of malaria (per 1,000 population at risk)'])
bed_net_correlation
# Out:
# np.float64(-0.6674882545213199)

# %% [markdown]
# #### 4.How has access to safely managed drinking water services in rural and urban areas changed over time in Ghana?

# %%
water_services_trend = ghana_df[['Year', 'People using safely managed drinking water services, rural (% of rural population)', \
                                 'People using safely managed drinking water services, urban (% of urban population)']]
water_services_trend
# Out:
#      Year  \
# 22   2007
# 76   2008
# 130  2009
# 184  2010
# 238  2011
# 292  2012
# 346  2013
# 400  2014
# 454  2015
# 508  2016
# 562  2017
#
#      People using safely managed drinking water services, rural (% of rural population)  \
# 22                                                3.86
# 76                                                4.54
# 130                                               5.23
# 184                                               5.94
# 238                                               6.67
# 292                                               7.42
# 346                                               8.19
# 400                                               8.98
# 454                                               9.78
# 508                                              10.61
# 562                                              11.45
#
#      People using safely managed drinking water services, urban (% of urban population)
# 22                                               39.28
# 76                                               40.94
# 130                                              42.60
# 184                                              44.28
# 238                                              45.98
# 292                                              47.70
# 346                                              49.43
# 400                                              51.17
# 454                                              52.93
# 508                                              54.71
# 562                                              56.50

# %% [markdown]
# #### 5. How has the use of safely managed sanitation services evolved in rural and urban areas of Ghana?

# %%
sanitation_services_trend = ghana_df[['Year', 'People using safely managed sanitation services, rural (% of rural population)', \
                                      'People using safely managed sanitation services, urban  (% of urban population)']]
sanitation_services_trend
# Out:
#      Year  \
# 22   2007
# 76   2008
# 130  2009
# 184  2010
# 238  2011
# 292  2012
# 346  2013
# 400  2014
# 454  2015
# 508  2016
# 562  2017
#
#     People using safely managed sanitation services, rural (% of rural population)  \
# 22                                             Unknown
# 76                                             Unknown
# 130                                            Unknown
# 184                                            Unknown
# 238                                            Unknown
# 292                                            Unknown
# 346                                            Unknown
# 400                                            Unknown
# 454                                            Unknown
# 508                                            Unknown
# 562                                            Unknown
#
#     People using safely managed sanitation services, urban  (% of urban population)
# 22                                             Unknown
# 76                                             Unknown
# 130                                            Unknown
# 184                                            Unknown
# 238                                            Unknown
# 292                                            Unknown
# 346                                            Unknown
# 400                                            Unknown
# 454                                            Unknown
# 508                                            Unknown
# 562                                            Unknown

# %% [markdown]
# #### 6.What is the rural vs. urban population distribution in Ghana, and how has it changed over time?

# %%
population_distribution = ghana_df[['Year', 'Rural population (% of total population)', 'Urban population (% of total population)']]
population_distribution
# Out:
#      Year  Rural population (% of total population)  \
# 22   2007                                     51.33
# 76   2008                                     50.65
# 130  2009                                     49.97
# 184  2010                                     49.29
# 238  2011                                     48.61
# 292  2012                                     47.93
# 346  2013                                     47.25
# 400  2014                                     46.58
# 454  2015                                     45.91
# 508  2016                                     45.25
# 562  2017                                     44.59
#
#      Urban population (% of total population)
# 22                                      48.67
# 76                                      49.35
# 130                                     50.03
# 184                                     50.71
# 238                                     51.39
# 292                                     52.07
# 346                                     52.75
# 400                                     53.42
# 454                                     54.09
# 508                                     54.75
# 562                                     55.41

# %% [markdown]
# #### 7.What is the impact of rural population growth on malaria incidence in Ghana?

# %%
rural_growth_corr = ghana_df['Rural population growth (annual %)'].corr(ghana_df['Incidence of malaria (per 1,000 population at risk)'])
rural_growth_corr
# Out:
# np.float64(0.6197575224288991)

# %% [markdown]
# #### 8.What is the trend of Ghana’s urban population growth, and how does it correlate with malaria incidence?

# %%
urban_growth_corr = ghana_df['Urban population growth (annual %)'].corr(ghana_df['Incidence of malaria (per 1,000 population at risk)'])
urban_growth_corr
# Out:
# np.float64(0.6631323382120582)

# %% [markdown]
# #### 9. Which year had the highest malaria incidence in Ghana, and what were the corresponding water and sanitation conditions?

# %%
max_malaria_year = ghana_df.loc[ghana_df['Incidence of malaria (per 1,000 population at risk)'].idxmax()]
max_malaria_year
# Out:
# Country Name                                                                                                    Ghana
# Year                                                                                                             2011
# Country Code                                                                                                      GHA
# Incidence of malaria (per 1,000 population at risk)                                                            379.52
# Malaria cases reported                                                                                      1041260.0
# Use of insecticide-treated bed nets (% of under-5 population)                                                    39.0
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever)                          52.6
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)                       39.388704
# People using safely managed drinking water services (% of population)                                           26.87
# People using safely managed drinking water services, rural (% of rural population)                               6.67
# People using safely managed drinking water services, urban (% of urban population)                              45.98
# People using safely managed sanitation services (% of population)                                             Unknown
# People using safely managed sanitation services, rural (% of rural population)                                Unknown
# People using safely managed sanitation services, urban  (% of urban population)                               Unknown
# Rural population (% of total population)                                                                        48.61
# Rural population growth (annual %)                                                                               1.03
# Urban population (% of total population)                                                                        51.39
# Urban population growth (annual %)                                                                               3.76
# People using at least basic drinking water services (% of population)                                           75.37
# People using at least basic drinking water services, rural (% of rural population)                              62.97
# People using at least basic drinking water services, urban (% of urban population)                               87.1
# People using at least basic sanitation services (% of population)                                               14.57
# People using at least basic sanitation services, rural (% of rural population)                                   8.83
# People using at least basic sanitation services, urban  (% of urban population)                                  20.0
# latitude                                                                                                     7.946527
# longitude                                                                                                   -1.023194
# geometry                                                                                   POINT (7.946527 -1.023194)
# Sanitation Improvement                                                                                        Unknown
# Name: 238, dtype: object

# %% [markdown]
# # VISUALIZATION
#
# ## 1.Overall Trend of Malaria Incidence Across African Countries Over Time

# %%
malaria_trend.plot(kind='line', marker='o')
plt.title('Trend of Malaria Incidence Over Time')
plt.xlabel('Year')
plt.ylabel('Average Malaria Incidence (per 1,000 at risk)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 2.Top 5 African Countries with the Highest Malaria Incidence

# %%
top_5_countries.plot(kind='bar', color='salmon')
plt.title('Top 5 African Countries with Highest Malaria Incidence')
plt.xlabel('Country')
plt.xticks(rotation=45)
plt.grid(False)
plt.ylabel('Average Malaria Incidence (per 1,000 at risk)')
plt.show()

# %% [markdown]
# ## 3.Line Plot for Malaria Incidence Over Time in Ghana

# %%
malaria_trend.plot(x='Year', 
                   y='Incidence of malaria (per 1,000 population at risk)', 
                   kind='line', 
                   figsize=(10, 6), 
                   title='Malaria Incidence in Ghana Over Time', 
                   grid=False)

plt.show()

# %% [markdown]
# ## 4.Bar Plot for Malaria Cases Reported by Year

# %%
malaria_cases_trend.plot(x='Year', 
                         y='Malaria cases reported', 
                         kind='bar', figsize=(10, 6), 
                         title='Malaria Cases Reported in Ghana Over Time',
                         grid=False)
plt.show()

# %% [markdown]
# ## 5.Line Plot for Water Services Access Over Time

# %%
water_services_trend.plot(x='Year', 
                          figsize=(10, 6), 
                          title='Access to Safely Managed Drinking Water Services in Ghana')
plt.show()

# %% [markdown]
# ## 6.Dual Line Plot for Rural vs Urban Population Distribution

# %%
population_distribution.plot(x='Year', 
                             figsize=(10, 6), 
                             title='Rural vs Urban Population Distribution in Ghana')
plt.show()
